# %% [markdown]
# ## RMSD Tutorial Example
#
# This is a simple example of calculating the RMSD between a predicted SARS-2 spike protein model using SWISS (swiss1) and an experimentally determined model from the Protein Data Bank (6vxx). This notebook directly follows the RMSD tutorial from Module 3 of *Multiscale Biological Modeling: A Free Online Course*.
#
# **Make sure that this notebook is in the same file directory as the structures files.**

# %%
from prody import *

# %%
def printMatch(match):
    print('Chain 1 : {}'.format(match[0]))
    print('Chain 2 : {}'.format(match[1]))
    print('Length : {}'.format(len(match[0])))
    print('Seq identity: {}'.format(match[2]))
    print('Seq overlap : {}'.format(match[3]))
    print('RMSD : {}\n'.format(calcRMSD(match[0], match[1])))

# %%
struct1 = parsePDB('swiss1.pdb')
# Out:
# @> 26157 atoms and 1 coordinate set(s) were parsed in 0.27s.

# %%
struct2 = parsePDB('6vxx.pdb')
# Out:
# @> 23694 atoms and 1 coordinate set(s) were parsed in 0.25s.

# %%
matches = matchChains(struct1,struct2,seqid=75,overlap=80)
# Out:
# @> Checking AtomGroup swiss1: 3 chains are identified
# @> WARNING no one-letter mapping found for <Residue: NAG 1301 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1302 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1305 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1306 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1307 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1308 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1309 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1310 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1311 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1316 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1321 from Chain A from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1301 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1302 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1305 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1306 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1307 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1308 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1309 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1310 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1311 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1316 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1321 from Chain B from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1301 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1302 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1305 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1306 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1307 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1308 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1309 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1310 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1311 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1316 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1321 from Chain C from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain D from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain D from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain E from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain E from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain F from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain F from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain G from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain G from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain H from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain H from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain I from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain I from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain J from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain J from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain K from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain K from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain L from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain L from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain M from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain M from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain N from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain N from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain O from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain O from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain P from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain P from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain Q from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain Q from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 1 from Chain R from 6vxx (14 atoms)>
# @> WARNING no one-letter mapping found for <Residue: NAG 2 from Chain R from 6vxx (14 atoms)>
# @> Checking AtomGroup 6vxx: 18 chains are identified
# @> Trying to match chains based on residue numbers and names:
# @>   Comparing Chain A from swiss1 (len=1120) and Chain A from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain B from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain C from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain D from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain E from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain F from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain G from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain H from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain I from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain J from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain K from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain L from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain M from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain N from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain O from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain P from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain Q from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain R from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain A from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain B from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain C from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain D from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain E from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain F from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain G from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain H from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain I from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain J from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain K from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain L from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain M from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain N from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain O from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain P from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain Q from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain R from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain A from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain B from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain C from 6vxx (len=983):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain D from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain E from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain F from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain G from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain H from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain I from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain J from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain K from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain L from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain M from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain N from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain O from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain P from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain Q from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain R from 6vxx (len=2):
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @> Trying to match chains based on local sequence alignment:
# @>  Comparing Chain A from swiss1 (len=1120) and Chain A from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain A from swiss1 (len=1120) and Chain B from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain A from swiss1 (len=1120) and Chain C from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain A from swiss1 (len=1120) and Chain D from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain E from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain F from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain G from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain H from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain I from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain J from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain K from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain L from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain M from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain N from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain O from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain P from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain Q from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain A from swiss1 (len=1120) and Chain R from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain A from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain B from swiss1 (len=1120) and Chain B from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain B from swiss1 (len=1120) and Chain C from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain B from swiss1 (len=1120) and Chain D from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain E from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain F from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain G from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain H from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain I from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain J from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain K from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain L from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain M from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain N from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain O from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain P from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain Q from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain B from swiss1 (len=1120) and Chain R from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain A from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain C from swiss1 (len=1120) and Chain B from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain C from swiss1 (len=1120) and Chain C from 6vxx (len=983):
# @> 	Match: 971 residues match with 99% sequence identity and 87% overlap.
# @>  Comparing Chain C from swiss1 (len=1120) and Chain D from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain E from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain F from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain G from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain H from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain I from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain J from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain K from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain L from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain M from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain N from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain O from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain P from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain Q from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).
# @>  Comparing Chain C from swiss1 (len=1120) and Chain R from 6vxx (len=2):
# @> WARNING Matching chains resulted in empty alignment.
# @> 	Failed to match chains (seqid=0%, overlap=0%).

# %%
for match in matches:
    printMatch(match)
# Out:
# Chain 1 : AtomMap Chain A from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 32.40892431179063
#
# Chain 1 : AtomMap Chain A from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 47.037995021072824
#
# Chain 1 : AtomMap Chain A from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 58.94181412098118
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 67.30652364236154
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 48.81581935108342
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 33.740250682476784
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 51.527440685696
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 78.60491318302446
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 98.77924720244151
# Seq overlap : 86.69642857142857
# RMSD : 42.445296947844895

# %% [markdown]
# ### Calculating RMSD of two chains

# %%
first_ca = matches[4][0]
second_ca = matches[4][1]
calcTransformation(first_ca, second_ca).apply(first_ca);
calcRMSD(first_ca,second_ca)
# Out:
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target

# %% [markdown]
# ### Merging multiple chains to compute RMSD of an overall structure

# %%
first_ca = matches[0][0] + matches[4][0] + matches[8][0]
second_ca = matches [0][1] + matches[4][1] + matches[8][1]
calcTransformation(first_ca, second_ca).apply(first_ca);
calcRMSD(first_ca, second_ca)
